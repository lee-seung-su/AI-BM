# %% [markdown]
# ## 싸인 함수 회귀분석 (Sine Regression)

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

print(tf.__version__)
# Out:
# 2.3.0

# %% [markdown]
# ## 데이터 생성

# %% [markdown]
# #### Spiral Data Generation 함수 정의

# %%
theta = 4

# generate the data
def generate_spiral_dataset(num_data, num_class, num_dim=2):
    input_data = np.zeros((num_data*num_class,num_dim)) # data matrix (each row = single example)
    output_data = np.zeros(num_data*num_class, dtype='uint8') # class labels

    for j in range(num_class):
      ix = range(num_data*j,num_data*(j+1))
      r = np.linspace(0.0,1,num_data) # radius [0,1]
      t = np.linspace(j*theta,(j+1)*theta,num_data) + np.random.randn(num_data)*0.2 # theta [0, 4]
      input_data[ix] = np.c_[r*np.sin(t), r*np.cos(t)]
      output_data[ix] = j
    
    return input_data, output_data

# %% [markdown]
# #### 훈련 데이터, 테스트 데이터 생성

# %%
N = 200 # number of points per class
D = 2 # dimensionality
K = 3 # number of classes

train_x, train_y = generate_spiral_dataset(N, K, D)
test_x, test_y = generate_spiral_dataset(N, K, D)

# lets visualize the data:
plt.figure(figsize=(14,5))
plt.subplot(1,2,1)
plt.scatter(train_x[:, 0], train_x[:, 1], c=train_y, s=40, cmap=plt.cm.Spectral)
plt.xlabel("Train Dataset")
plt.subplot(1,2,2)
plt.scatter(test_x[:, 0], test_x[:, 1], c=test_y, s=40, cmap=plt.cm.Spectral)
plt.xlabel("Test Dataset")
plt.show()

# %% [markdown]
# ## 모델 정의

# %%
model = keras.Sequential([
    keras.layers.Dense(20, activation='relu', input_shape=[D]),
    keras.layers.Dense(20, activation='relu'),
    keras.layers.Dense(K, activation='softmax')
])

# %% [markdown]
# ## 모델 훈련

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(train_x, train_y, epochs=100)
# Out:
# Train on 600 samples
# Epoch 1/100
# 600/600 [==============================] - 0s 708us/sample - loss: 1.0544 - accuracy: 0.3967
# Epoch 2/100
# 600/600 [==============================] - 0s 58us/sample - loss: 1.0169 - accuracy: 0.5067
# Epoch 3/100
# 600/600 [==============================] - 0s 57us/sample - loss: 0.9789 - accuracy: 0.5167
# Epoch 4/100
# 600/600 [==============================] - 0s 58us/sample - loss: 0.9413 - accuracy: 0.5267
# Epoch 5/100
# 600/600 [==============================] - 0s 57us/sample - loss: 0.9034 - accuracy: 0.5417
# Epoch 6/100
# 600/600 [==============================] - 0s 56us/sample - loss: 0.8666 - accuracy: 0.5583
# Epoch 7/100
# 600/600 [==============================] - 0s 60us/sample - loss: 0.8312 - accuracy: 0.5667
# Epoch 8/100
# 600/600 [==============================] - 0s 61us/sample - loss: 0.8002 - accuracy: 0.5700
# Epoch 9/100
# 600/600 [==============================] - 0s 53us/sample - loss: 0.7710 - accuracy: 0.5867
# Epoch 10/100
# 600/600 [==============================] - 0s 58us/sample - loss: 0.7446 - accuracy: 0.5950
# Epoch 11/100
# 600/600 [==============================] - 0s 53us/sample - loss: 0.7196 - accuracy: 0.6033
# Epoch 12/100
# 600/600 [==============================] - 0s 60us/sample - loss: 0.6976 - accuracy: 0.6167
# Epoch 13/100
# 600/600 [==============================] - 0s 62us/sample - loss: 0.6760 - accuracy: 0.6417
# Epoch 14/100
# 600/600 [==============================] - 0s 60us/sample - loss: 0.6540 - accuracy: 0.6767
# Epoch 15/100
# 600/600 [==============================] - 0s 70us/sample - loss: 0.6350 - accuracy: 0.7133
# Epoch 16/100
# 600/600 [==============================] - 0s 71us/sample - loss: 0.6150 - accuracy: 0.7217
# Epoch 17/100
# 600/600 [==============================] - 0s 58us/sample - loss: 0.5971 - accuracy: 0.7200
# Epoch 18/100
# 600/600 [==============================] - 0s 68us/sample - loss: 0.5796 - accuracy: 0.7617
# Epoch 19/100
# 600/600 [==============================] - 0s 91us/sample - loss: 0.5613 - accuracy: 0.7733
# Epoch 20/100
# 600/600 [==============================] - 0s 88us/sample - loss: 0.5444 - accuracy: 0.7800
# Epoch 21/100
# 600/600 [==============================] - 0s 66us/sample - loss: 0.5280 - accuracy: 0.7883
# Epoch 22/100
# 600/600 [==============================] - 0s 65us/sample - loss: 0.5117 - accuracy: 0.7950
# Epoch 23/100
# 600/600 [==============================] - 0s 60us/sample - loss: 0.4960 - accuracy: 0.8017
# Epoch 24/100
# 600/600 [==============================] - 0s 55us/sample - loss: 0.4805 - accuracy: 0.8100
# Epoch 25/100
# 600/600 [==============================] - 0s 58us/sample - loss: 0.4648 - accuracy: 0.8250
# Epoch 26/100
# 600/600 [==============================] - 0s 58us/sample - loss: 0.4506 - accuracy: 0.8333
# Epoch 27/100
# 600/600 [==============================] - 0s 53us/sample - loss: 0.4354 - accuracy: 0.8433
# Epoch 28/100
# 600/600 [==============================] - 0s 53us/sample - loss: 0.4214 - accuracy: 0.8467
# Epoch 29/100
# 600/600 [==============================] - 0s 52us/sample - loss: 0.4067 - accuracy: 0.8583
# Epoch 30/100
# 600/600 [==============================] - 0s 55us/sample - loss: 0.3934 - accuracy: 0.8617
# Epoch 31/100
# 600/600 [==============================] - 0s 55us/sample - loss: 0.3804 - accuracy: 0.8717
# Epoch 32/100
# 600/600 [==============================] - 0s 55us/sample - loss: 0.3670 - accuracy: 0.8767
# Epoch 33/100
# 600/600 [==============================] - 0s 57us/sample - loss: 0.3546 - accuracy: 0.8833
# Epoch 34/100
# 600/600 [==============================] - 0s 60us/sample - loss: 0.3438 - accuracy: 0.8900
# Epoch 35/100
# 600/600 [==============================] - 0s 57us/sample - loss: 0.3302 - accuracy: 0.8917
# Epoch 36/100
# 600/600 [==============================] - 0s 53us/sample - loss: 0.3196 - accuracy: 0.9083
# Epoch 37/100
# 600/600 [==============================] - 0s 58us/sample - loss: 0.3088 - accuracy: 0.9067
# Epoch 38/100
# 600/600 [==============================] - 0s 55us/sample - loss: 0.2983 - accuracy: 0.9150
# Epoch 39/100
# 600/600 [==============================] - 0s 60us/sample - loss: 0.2880 - accuracy: 0.9200
# Epoch 40/100
# 600/600 [==============================] - 0s 55us/sample - loss: 0.2776 - accuracy: 0.9217
# Epoch 41/100
# 600/600 [==============================] - 0s 57us/sample - loss: 0.2684 - accuracy: 0.9267
# Epoch 42/100
# 600/600 [==============================] - 0s 55us/sample - loss: 0.2591 - accuracy: 0.9283
# Epoch 43/100
# 600/600 [==============================] - 0s 60us/sample - loss: 0.2501 - accuracy: 0.9333
# Epoch 44/100
# 600/600 [==============================] - 0s 60us/sample - loss: 0.2418 - accuracy: 0.9367
# Epoch 45/100
# 600/600 [==============================] - 0s 57us/sample - loss: 0.2336 - accuracy: 0.9367
# Epoch 46/100
# 600/600 [==============================] - 0s 58us/sample - loss: 0.2263 - accuracy: 0.9467
# Epoch 47/100
# 600/600 [==============================] - 0s 57us/sample - loss: 0.2186 - accuracy: 0.9433
# Epoch 48/100
# 600/600 [==============================] - 0s 58us/sample - loss: 0.2115 - accuracy: 0.9483
# Epoch 49/100
# 600/600 [==============================] - 0s 60us/sample - loss: 0.2048 - accuracy: 0.9467
# Epoch 50/100
# 600/600 [==============================] - 0s 62us/sample - loss: 0.1987 - accuracy: 0.9600
# Epoch 51/100
# 600/600 [==============================] - 0s 62us/sample - loss: 0.1923 - accuracy: 0.9517
# Epoch 52/100
# 600/600 [==============================] - 0s 55us/sample - loss: 0.1866 - accuracy: 0.9600
# Epoch 53/100
# 600/600 [==============================] - 0s 53us/sample - loss: 0.1814 - accuracy: 0.9633
# Epoch 54/100
# 600/600 [==============================] - 0s 58us/sample - loss: 0.1772 - accuracy: 0.9567
# Epoch 55/100
# 600/600 [==============================] - 0s 57us/sample - loss: 0.1715 - accuracy: 0.9650
# Epoch 56/100
# 600/600 [==============================] - 0s 57us/sample - loss: 0.1661 - accuracy: 0.9683
# Epoch 57/100
# 600/600 [==============================] - 0s 57us/sample - loss: 0.1624 - accuracy: 0.9667
# Epoch 58/100
# 600/600 [==============================] - 0s 62us/sample - loss: 0.1576 - accuracy: 0.9750
# Epoch 59/100
# 600/600 [==============================] - 0s 57us/sample - loss: 0.1549 - accuracy: 0.9683
# Epoch 60/100
# 600/600 [==============================] - 0s 58us/sample - loss: 0.1485 - accuracy: 0.9833
# Epoch 61/100
# 600/600 [==============================] - 0s 53us/sample - loss: 0.1458 - accuracy: 0.9767
# Epoch 62/100
# 600/600 [==============================] - 0s 58us/sample - loss: 0.1425 - accuracy: 0.9733
# Epoch 63/100
# 600/600 [==============================] - 0s 57us/sample - loss: 0.1385 - accuracy: 0.9800
# Epoch 64/100
# 600/600 [==============================] - 0s 55us/sample - loss: 0.1354 - accuracy: 0.9817
# Epoch 65/100
# 600/600 [==============================] - 0s 55us/sample - loss: 0.1316 - accuracy: 0.9833
# Epoch 66/100
# 600/600 [==============================] - 0s 52us/sample - loss: 0.1298 - accuracy: 0.9750
# Epoch 67/100
# 600/600 [==============================] - 0s 55us/sample - loss: 0.1259 - accuracy: 0.9833
# Epoch 68/100
# 600/600 [==============================] - 0s 52us/sample - loss: 0.1235 - accuracy: 0.9833
# Epoch 69/100
# 600/600 [==============================] - 0s 68us/sample - loss: 0.1205 - accuracy: 0.9883
# Epoch 70/100
# 600/600 [==============================] - 0s 53us/sample - loss: 0.1183 - accuracy: 0.9800
# Epoch 71/100
# 600/600 [==============================] - 0s 55us/sample - loss: 0.1152 - accuracy: 0.9883
# Epoch 72/100
# 600/600 [==============================] - 0s 53us/sample - loss: 0.1132 - accuracy: 0.9850
# Epoch 73/100
# 600/600 [==============================] - 0s 57us/sample - loss: 0.1112 - accuracy: 0.9883
# Epoch 74/100
# 600/600 [==============================] - 0s 57us/sample - loss: 0.1089 - accuracy: 0.9900
# Epoch 75/100
# 600/600 [==============================] - 0s 62us/sample - loss: 0.1064 - accuracy: 0.9883
# Epoch 76/100
# 600/600 [==============================] - 0s 57us/sample - loss: 0.1041 - accuracy: 0.9917
# Epoch 77/100
# 600/600 [==============================] - 0s 57us/sample - loss: 0.1024 - accuracy: 0.9917
# Epoch 78/100
# 600/600 [==============================] - 0s 60us/sample - loss: 0.1008 - accuracy: 0.9900
# Epoch 79/100
# 600/600 [==============================] - 0s 60us/sample - loss: 0.0986 - accuracy: 0.9967
# Epoch 80/100
# 600/600 [==============================] - 0s 53us/sample - loss: 0.0971 - accuracy: 0.9900
# Epoch 81/100
# 600/600 [==============================] - 0s 50us/sample - loss: 0.0957 - accuracy: 0.9917
# Epoch 82/100
# 600/600 [==============================] - 0s 55us/sample - loss: 0.0940 - accuracy: 0.9883
# Epoch 83/100
# 600/600 [==============================] - 0s 55us/sample - loss: 0.0921 - accuracy: 0.9967
# Epoch 84/100
# 600/600 [==============================] - 0s 57us/sample - loss: 0.0903 - accuracy: 0.9917
# Epoch 85/100
# 600/600 [==============================] - 0s 52us/sample - loss: 0.0890 - accuracy: 0.9900
# Epoch 86/100
# 600/600 [==============================] - 0s 57us/sample - loss: 0.0872 - accuracy: 0.9933
# Epoch 87/100
# 600/600 [==============================] - 0s 52us/sample - loss: 0.0858 - accuracy: 0.9933
# Epoch 88/100
# 600/600 [==============================] - 0s 55us/sample - loss: 0.0844 - accuracy: 0.9933
# Epoch 89/100
# 600/600 [==============================] - 0s 53us/sample - loss: 0.0838 - accuracy: 0.9917
# Epoch 90/100
# 600/600 [==============================] - 0s 57us/sample - loss: 0.0821 - accuracy: 0.9933
# Epoch 91/100
# 600/600 [==============================] - 0s 53us/sample - loss: 0.0800 - accuracy: 0.9950
# Epoch 92/100
# 600/600 [==============================] - 0s 55us/sample - loss: 0.0797 - accuracy: 0.9950
# Epoch 93/100
# 600/600 [==============================] - 0s 57us/sample - loss: 0.0784 - accuracy: 0.9883
# Epoch 94/100
# 600/600 [==============================] - 0s 62us/sample - loss: 0.0778 - accuracy: 0.9900
# Epoch 95/100
# 600/600 [==============================] - 0s 57us/sample - loss: 0.0761 - accuracy: 0.9933
# Epoch 96/100
# 600/600 [==============================] - 0s 55us/sample - loss: 0.0751 - accuracy: 0.9933
# Epoch 97/100
# 600/600 [==============================] - 0s 55us/sample - loss: 0.0740 - accuracy: 0.9917
# Epoch 98/100
# 600/600 [==============================] - 0s 58us/sample - loss: 0.0729 - accuracy: 0.9950
# Epoch 99/100
# 600/600 [==============================] - 0s 57us/sample - loss: 0.0718 - accuracy: 0.9950
# Epoch 100/100
# 600/600 [==============================] - 0s 55us/sample - loss: 0.0711 - accuracy: 0.9950

# %% [markdown]
# ## 테스트

# %%
test_output_pred = model.predict(test_x)

plt.figure(figsize=(14,5))
plt.subplot(1,2,1)
plt.scatter(test_x[:, 0], test_x[:, 1], c=test_y, s=40, cmap=plt.cm.Spectral)
plt.xlabel("Test Dataset")
plt.subplot(1,2,2)
plt.scatter(test_x[:, 0], test_x[:, 1], c=test_output_pred, s=40, cmap=plt.cm.Spectral)
plt.xlabel("Prediction")
plt.show()
